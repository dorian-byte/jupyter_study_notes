# %%
from pprint import pprint

# %%
mountains = {
    "Mount Everest": 8848,
    "K2": 8611,
    "Kangchenjunga": 8586,
    "Lhotse": 8516,
    "Makalu": 8485,
    "Cho Oyu": 8188,
    "Dhaulagiri": 8167,
    "Manaslu": 8163,
    "Nanga Parbat": 8126,
    "Annapurna": 8091,
    "Gasherbrum I": 8080,
    "Broad Peak": 8051,
    "Gasherbrum II": 8035,
    "Shishapangma": 8027,
    "Gasherbrum III": 7952,
    "Gasherbrum IV": 7925,
    "Distaghil Sar": 7885,
    "Ngadi Chuli": 7871,
    "Gasherbrum V": 7852,
    "Gasherbrum VI": 7832,
    "Gasherbrum VII": 7820,
    "Gasherbrum VIII": 7810,
    "Gasherbrum IX": 7795,
    "Gasherbrum X": 7790,
    "Shispare": 7760
}

# %%
print(mountains)
# Out:
# {'Mount Everest': 8848, 'K2': 8611, 'Kangchenjunga': 8586, 'Lhotse': 8516, 'Makalu': 8485, 'Cho Oyu': 8188, 'Dhaulagiri': 8167, 'Manaslu': 8163, 'Nanga Parbat': 8126, 'Annapurna': 8091, 'Gasherbrum I': 8080, 'Broad Peak': 8051, 'Gasherbrum II': 8035, 'Shishapangma': 8027, 'Gasherbrum III': 7952, 'Gasherbrum IV': 7925, 'Distaghil Sar': 7885, 'Ngadi Chuli': 7871, 'Gasherbrum V': 7852, 'Gasherbrum VI': 7832, 'Gasherbrum VII': 7820, 'Gasherbrum VIII': 7810, 'Gasherbrum IX': 7795, 'Gasherbrum X': 7790, 'Shispare': 7760}

# %%
pprint(mountains)
# Out:
# {'Annapurna': 8091,
#  'Broad Peak': 8051,
#  'Cho Oyu': 8188,
#  'Dhaulagiri': 8167,
#  'Distaghil Sar': 7885,
#  'Gasherbrum I': 8080,
#  'Gasherbrum II': 8035,
#  'Gasherbrum III': 7952,
#  'Gasherbrum IV': 7925,
#  'Gasherbrum IX': 7795,
#  'Gasherbrum V': 7852,
#  'Gasherbrum VI': 7832,
#  'Gasherbrum VII': 7820,
#  'Gasherbrum VIII': 7810,
#  'Gasherbrum X': 7790,
#  'K2': 8611,
#  'Kangchenjunga': 8586,
#  'Lhotse': 8516,
#  'Makalu': 8485,
#  'Manaslu': 8163,
#  'Mount Everest': 8848,
#  'Nanga Parbat': 8126,
#  'Ngadi Chuli': 7871,
#  'Shishapangma': 8027,
#  'Shispare': 7760}

# %%
paintings = [    "Salvator Mundi",     "When Will You Marry?",     "The Card Players",     "Women of Algiers (Version O)",     "Interchange",     "The Scream",     "Nafea Faa Ipoipo",     "Number 17A",     "Portrait of Adele Bloch-Bauer I",     "The Persistence of Memory"]

# %%
print(paintings)
# Out:
# ['Salvator Mundi', 'When Will You Marry?', 'The Card Players', 'Women of Algiers (Version O)', 'Interchange', 'The Scream', 'Nafea Faa Ipoipo', 'Number 17A', 'Portrait of Adele Bloch-Bauer I', 'The Persistence of Memory']

# %%
pprint(paintings)
# Out:
# ['Salvator Mundi',
#  'When Will You Marry?',
#  'The Card Players',
#  'Women of Algiers (Version O)',
#  'Interchange',
#  'The Scream',
#  'Nafea Faa Ipoipo',
#  'Number 17A',
#  'Portrait of Adele Bloch-Bauer I',
#  'The Persistence of Memory']

# %% [markdown]
# <font color=red>👇🏻 Jamie’s note:
#
# A TypeError is raised when you try to perform an operation or function call on an object of an inappropriate type. For example, you might get a TypeError if you try to concatenate a string with an integer.
#
# A ValueError is raised when you pass an argument to a function that has the right type but an inappropriate value. For example, you might get a ValueError if you try to call int("abc") to convert a string to an integer, because the string "abc" is not a valid integer.

# %%
from datetime import datetime

# %%
datetime(2011,1,1)
# Out:
# datetime.datetime(2011, 1, 1, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 1, 10, 10, 49, 0, 661185)

# %%
from datetime import date

# %%
date(2011,1,1)
# Out:
# datetime.date(2011, 1, 1)

# %%
date.today()
# Out:
# datetime.date(2023, 1, 10)

# %%
user_input = input("Enter a date (YYYY-MM-DD)")
# Out:
# Enter a date (YYYY-MM-DD)2011-08-20

# %%
datetime.fromisoformat(user_input)
# Out:
# datetime.datetime(2011, 8, 20, 0, 0)

# %%
from datetime import datetime

# create a datetime object
now = datetime.now()

# print the year, month, and day
print("Year:", now.year)
print("Month:", now.month)
print("Day:", now.day)

# print the hour, minute, and second
print("Hour:", now.hour)
print("Minute:", now.minute)
print("Second:", now.second)

# print the microsecond and timezone
print("Microsecond:", now.microsecond)
print("Timezone:", now.tzinfo)

# print week of day, Monday=0, Sunday=6
print("Week of day:", now.weekday())
# Out:
# Year: 2023
# Month: 1
# Day: 10
# Hour: 13
# Minute: 42
# Second: 6
# Microsecond: 917947
# Timezone: None
# Week of day: 1

# %%
from datetime import date

# create a date object
td = date.today()

# print the year, month, and day
print("Year:", td.year)
print("Month:", td.month)
print("Day:", td.day)

# print week of day, Monday=0, Sunday=6
print("Week of day:", td.weekday())
# Out:
# Year: 2023
# Month: 1
# Day: 10
# Week of day: 1

# %%
input_ = ["2022", "11", "8"]

from datetime import date
def make_a_date(values):
    return date(int(values[0]),int(values[1]),int(values[2]))

make_a_date(input_)
# Out:
# datetime.date(2022, 11, 8)

# %% [markdown]
# Complete the function to convert the UNIX timestamp in the parameter ts to a datetime.
#
# For example, given the value 467056213 for ts, your function would return a datetime the represents Friday, October 19, 1984 5:50:13 PM.

# %%
datetime.fromtimestamp(467056213)
# Out:
# datetime.datetime(1984, 10, 19, 10, 50, 13)

# %%
# to get dayofweek
from datetime import date
date.today().weekday()
# Out:
# 1

# %%
from datetime import datetime, timedelta

wd1 = datetime.now().weekday()
wd2 = date.today().weekday()

# %%
wd1 == wd2, wd1
# Out:
# (True, 1)

# %% [markdown]
# #### 1 Just a date
#
# Add code below to make the function return this specific date/time value: 1:13pm on January 28, 1998:

# %%
from datetime import datetime
def a_specific_date():
    return datetime(1998,1,28,13,13)

# %% [markdown]
# #### 2 Add 30 minutes
# Submitted on Today at 12:13 PM
# The following function gets a datetime value as the parameter when. Please complete the function so that it returns a datetime that is thirty minutes later.
#
# For example, if the value passed into the function is 2021-02-01 9:00am, then you should return a datetime value that represents 2021-02-01 9:30am.

# %%
from datetime import timedelta
def add_thirty_minutes(when):
    return when + timedelta(minutes=30)

# %% [markdown]
# #### 3 Strings to dates
#
# Please complete the function that will take three strings in a list, one for the year, one for the month, and one for the day, and have it return a date that represents that day.
#
# For example, let's say your function got the following input: ["2022", "11", "8"]. Your function should return a date object representing November 8, 2022.

# %%
from datetime import date
def make_a_date(values):
    return date(int(values[0]),int(values[1]),int(values[2]))

# %% [markdown]
# #### 4 Find the difference
# Submitted on Today at 12:32 PM
# Complete the function to return the total number of days between two dates represented by date objects.
#
# For example, given the first date of Jan 1, 2020, and the second date of Feb 2, 2022, then your function would return 763 which is the total number of days between those.
#
# Your function should always return a positive integer.

# %%
from datetime import datetime, timedelta

def date_diff_in_days(first, second):
    return abs((second-first).days)

# %% [markdown]
# #### 5 Dates between two dates
# Complete the following function to return a list that contains the start date, then all of the dates up to and including end.
#
# For example, if start is Jan 1, 2002, and end is Jan 10, 2022, then you would return a list that contains the following date values:
#
# ```Python
# date(2002, 1, 1)
# date(2002, 1, 2)
# date(2002, 1, 3)
# date(2002, 1, 4)
# date(2002, 1, 5)
# date(2002, 1, 6)
# date(2002, 1, 7)
# date(2002, 1, 8)
# date(2002, 1, 9)
# date(2002, 1, 10)
# ```

# %%
from datetime import datetime, timedelta
def the_days_of_our_lives(start, end):
    lst = []
    for i in range((end-start).days + 1):
        lst.append(start)
        start+=timedelta(days=1)
    return lst

# %% [markdown]
# #### 6 UNIX timestamp to `date`
# Complete the function to convert the UNIX timestamp in the parameter ts to a datetime.
#
# For example, given the value 467056213 for ts, your function would return a datetime the represents Friday, October 19, 1984 5:50:13 PM.

# %%
from datetime import datetime
def stamp_my_hand(ts):
    return datetime.fromtimestamp(ts) #note: don't forget the "datetime."

# %% [markdown]
# #### 7 I'll gladly pay you Tuesday...
# Complete the function that returns a date that represents next Tuesday.

# %%
from datetime import date,timedelta
def hamburger_payment_due():
    return date.today() - timedelta(days=date.today().weekday() - 8)

# %% [markdown]
# #### 8 On Wednesdays We Wear Pink
# Complete the function to return the number of months whose first day falls on a Wednesday from January 2000 through December 2022.

# %%
from datetime import date, timedelta
def wednesday_wilderness():
    start, end = date(2000,1,1), date(2022,12,31)
    lst = []
    for i in range((end-start).days+1):
        if start.day==1 and start.weekday()==2:
            lst.append(start)
        start+=timedelta(days=1)
    return len(lst)

# %%
wednesday_wilderness()
# Out:
# 38

# %% [markdown]
# QuerySet

# %% [markdown]
# <div class="markdown prose w-full break-words dark:prose-invert light">
# <ol>
#    <li>Filter objects by a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# filtered_objects = MyModel.objects.<span class="hljs-built_in">filter</span>(field_name=<span class="hljs-string">'some value'</span>)
# </code></div></div></pre>
# <ol start="2">
#    <li>Exclude objects by a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# excluded_objects = MyModel.objects.exclude(field_name=<span class="hljs-string">'some value'</span>)
# </code></div></div></pre>
# <ol start="3">
#    <li>Order objects by a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# ordered_objects = MyModel.objects.order_by(<span class="hljs-string">'field_name'</span>)
# </code></div></div></pre>
# <ol start="4">
#    <li>Get the first or last object:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# first_object = MyModel.objects.first()
# last_object = MyModel.objects.last()
# </code></div></div></pre>
# <ol start="5">
#    <li>Get a specific object by its primary key:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# object_by_pk = MyModel.objects.get(pk=<span class="hljs-number">1</span>)
# </code></div></div></pre>
# <ol start="6">
#    <li>Get a set of unique values for a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# unique_field_values = MyModel.objects.values_list(<span class="hljs-string">'field_name'</span>, flat=<span class="hljs-literal">True</span>).distinct()
# </code></div></div></pre>
# <ol start="7">
#    <li>Get the minimum or maximum value for a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-sql"><span class="hljs-keyword">from</span> myapp.models import MyModel
# min_value <span class="hljs-operator">=</span> MyModel.objects.aggregate(<span class="hljs-built_in">Min</span>(<span class="hljs-string">'field_name'</span>))
# max_value <span class="hljs-operator">=</span> MyModel.objects.aggregate(<span class="hljs-built_in">Max</span>(<span class="hljs-string">'field_name'</span>))
# </code></div></div></pre>
# <ol start="8">
#    <li>Perform a full-text search:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> django.db.models <span class="hljs-keyword">import</span> Q
# <span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# search_results = MyModel.objects.<span class="hljs-built_in">filter</span>(Q(field_name__contains=<span class="hljs-string">'search term'</span>))
# </code></div></div></pre>
# <ol start="9">
#    <li>Perform a join with another table:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel, OtherModel
# objects_with_related_data = MyModel.objects.select_related(<span class="hljs-string">'other_model_field'</span>).<span class="hljs-built_in">filter</span>(other_model_field__field_name=<span class="hljs-string">'value'</span>)
# </code></div></div></pre>
# <ol start="10">
#    <li>Group by a certain field:</li>
# </ol>
# <pre><div class="bg-black mb-4 rounded-md"><div class="flex items-center relative text-gray-200 bg-gray-800 px-4 py-2 text-xs font-sans"><button class="flex ml-auto gap-2"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-4 w-4" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg" data-darkreader-inline-stroke="" style="--darkreader-inline-stroke:currentColor;"><path d="M16 4h2a2 2 0 0 1 2 2v14a2 2 0 0 1-2 2H6a2 2 0 0 1-2-2V6a2 2 0 0 1 2-2h2"></path><rect x="8" y="2" width="8" height="4" rx="1" ry="1"></rect></svg>Copy code</button></div><div class="p-4 overflow-y-auto"><code class="!whitespace-pre-wrap hljs language-python"><span class="hljs-keyword">from</span> myapp.models <span class="hljs-keyword">import</span> MyModel
# grouped_objects = MyModel.objects.values(<span class="hljs-string">'field_name'</span>).annotate(count=Count(<span class="hljs-string">'pk'</span>))
# </code></div></div></pre>
# <p>

# %% [markdown]
# ![Screenshot%202023-01-12%20at%207.56.03%20AM.png](attachment:Screenshot%202023-01-12%20at%207.56.03%20AM.png)

# %% [markdown]
# ![Screenshot%202023-01-12%20at%207.56.10%20AM.png](attachment:Screenshot%202023-01-12%20at%207.56.10%20AM.png)

# %% [markdown]
# <font color=red>👇🏻 Jamie’s note: Django Notes

# %% [markdown]
# ```Django
# {% load static %}
#
# <link rel="stylesheet" href="{% static "css/recipes.css" %}">
# ```
